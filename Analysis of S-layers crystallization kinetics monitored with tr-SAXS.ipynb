# %% [markdown]
# ### exploring with the 33mg dataset

# %% [markdown]
# #### 0. store csv in array

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
from sklearn.decomposition import FastICA, PCA

filename='./data/33_array.csv'

# %%
### NUMPY OPTION ###
# see https://docs.scipy.org/doc/numpy/reference/generated/numpy.genfromtxt.html
data = genfromtxt(filename, delimiter=',')
data
# Out:
# array([[ 3.01831e+04,  3.02550e+04,  3.03114e+04, ...,  9.74821e+04,
#          9.46660e+04,  9.52373e+04],
#        [ 3.04941e+04,  3.06469e+04,  3.20484e+04, ...,  9.10544e+04,
#          8.81612e+04,  9.08871e+04],
#        [ 2.98168e+04,  2.96970e+04,  3.16563e+04, ...,  8.26171e+04,
#          8.03466e+04,  8.18510e+04],
#        ...,
#        [ 7.74004e+01, -7.68034e+01, -7.70139e+01, ...,  1.37684e+02,
#          1.38079e+02,  1.69514e+01],
#        [ 3.09022e+01,  3.16378e+02,  1.72826e+02, ..., -2.56144e+02,
#          3.16655e+02,  3.19855e+01],
#        [-2.16273e+01, -1.65366e+02, -9.39888e+01, ...,  1.20696e+02,
#         -2.21202e+01, -2.07606e+01]])

# %%
plt.imshow(np.log(data.T), cmap='hot',vmin=0,vmax=10,origin='upper')
plt.show()

# %%
data.shape
# Out:
# (791, 153)

# %% [markdown]
# #### 1. PCA

# %%
# Compute PCA
pca = PCA(n_components=3)
H = pca.fit_transform(data)  # Reconstruct signals based on orthogonal components

# %%
#H
plt.semilogx(H)

# %% [markdown]
# #### 1. fastICA

# %%
# Compute ICA
ica = FastICA(n_components=3)
S_ = ica.fit_transform(data)  # Reconstruct signals
A_ = ica.mixing_  # Get estimated mixing matrix

# %%
#S_
plt.semilogx(S_)

# %%
#A_
plt.plot(A_)

# %%
#ica.mean_
