# %% [markdown]
# ### exploring with the 33mg dataset

# %% [markdown]
# #### 0. store csv in array

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
from sklearn.decomposition import FastICA, PCA

filename='./data/33_array.csv'

# %%
### NUMPY OPTION ###
# see https://docs.scipy.org/doc/numpy/reference/generated/numpy.genfromtxt.html
data = genfromtxt(filename, delimiter=',')
data
# Out:
# array([[ 1.44788e+04,  2.20822e+04,  2.37760e+04, ...,  9.74821e+04,
#          9.46660e+04,  9.52373e+04],
#        [ 1.37852e+04,  2.25457e+04,  2.43392e+04, ...,  9.10544e+04,
#          8.81612e+04,  9.08871e+04],
#        [ 1.30655e+04,  2.27637e+04,  2.41668e+04, ...,  8.26171e+04,
#          8.03466e+04,  8.18510e+04],
#        ...,
#        [-7.43562e+01,  1.09622e+02,  4.57155e+01, ...,  1.37684e+02,
#          1.38079e+02,  1.69514e+01],
#        [ 3.37011e+01, -1.83749e+02, -1.84613e+02, ..., -2.56144e+02,
#          3.16655e+02,  3.19855e+01],
#        [-1.93881e+01,  1.23290e+02, -2.23660e+01, ...,  1.20696e+02,
#         -2.21202e+01, -2.07606e+01]])

# %%
plt.imshow(np.log(data.T), cmap='hot',vmin=0,vmax=10,origin='upper')
plt.show()

# %%
data.shape
# Out:
# (791, 170)

# %% [markdown]
# #### 1. PCA

# %% [markdown]
# #### 1. fastICA

# %%
# Compute ICA
ica = FastICA(n_components=3)
S_ = ica.fit_transform(data)  # Reconstruct signals
A_ = ica.mixing_  # Get estimated mixing matrix

# %%
S_
plt.plot(S_)
# Out:
# [<matplotlib.lines.Line2D at 0x12281db00>,
#  <matplotlib.lines.Line2D at 0x12281dc50>,
#  <matplotlib.lines.Line2D at 0x12281dda0>]

# %%
A_
plt.plot(A_)
# Out:
# [<matplotlib.lines.Line2D at 0x1213b62e8>,
#  <matplotlib.lines.Line2D at 0x1213b6438>,
#  <matplotlib.lines.Line2D at 0x1213b6588>]
